# %% [markdown]
# <a href="https://colab.research.google.com/github/Fedo682/FlightpathdelaysProject/blob/main/notebooks/flightDelays.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Flight Delays Data Science Project

# %% [markdown]
# ## We will start loading the data from the datasets

# %% [markdown]
# importing essential python libaries

# %%
import numpy as np
import pandas as pd

# %%
airport_raw = pd.read_csv("../data/Raw/airports.csv")
airport_raw.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_14095/967713103.py in <cell line: 0>()
# ----> 1 airport_raw = pd.read_csv("../data/Raw/airports.csv")
#       2 airport_raw.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
delays_raw = pd.read_excel("../data/Raw/RP4_APT_ATFM_ARR_2026_Jan_Feb.xlsx", sheet_name="APT_ATFM_APT", header=4)
delays_raw.head()

# %% [markdown]
# * now we have read the Dataframes next we will conduct cleaning and merging the datasets
