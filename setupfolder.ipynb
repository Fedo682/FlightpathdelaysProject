# %% [markdown]
# <a href="https://colab.research.google.com/github/Fedo682/FlightpathdelaysProject/blob/main/setupfolder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to our Flight Delay Project")
# Out:
# Welcome to our Flight Delay Project
